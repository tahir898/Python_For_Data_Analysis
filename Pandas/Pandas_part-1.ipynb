# %% [markdown]
# # pandas part-1
#  1. introduction
#  2. head()
#  3. tail()
#  4. reading(1.excell, 2.csv 3.website html)

# %% [markdown]
# # * Introduction

# %% [markdown]
# # wht pandas?
# 1. DA, DS, DE, BA
# 2. pandas is a python library used for working with data sets
# 3.it has functions for analyzing , cleaning , exploring , and manipulating data

# %% [markdown]
# # * Why pandas?
# . pandas allows us to analyze big data and make conclusions based on statistical theories
# . pandas can clean messy data sets, and make them readable  and relevent
# . relevant data is very important in data science

# %% [markdown]
# # *advandatges of using pandas
# 1. fast and efficient for manipulating and analyzing data
# 2. data from different file objects can be loaded
# 3. easy handaling of missing data in floating point as well as non- floating point data
# 4. size mutability: columns can be inserted and deleted from dataFrame and higher dimensional objects
# 5. data set merging and joining
# 6. flexible reshaping and pioviting of data sets
# 7. provides time- series functionality
# 8. powerful groups by functionality from performing split- apply- combine operations on data sets

# %%
import pandas as pd

# %%
df=pd.read_csv("services.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# # * reading top 5 data

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(15)
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 0    1            1         NaN               NaN            NaN
# 1    2            2         NaN               NaN            NaN
# 2    3            3         NaN               NaN            NaN
# 3    4            4         NaN               NaN            NaN
# 4    5            5         NaN               NaN            NaN
# 5    6            6         NaN               NaN            NaN
# 6    7            7         NaN               NaN            NaN
# 7    8            8         NaN               NaN            NaN
# 8    9            9         NaN               NaN            NaN
# 9   10           10         NaN               NaN            NaN
# 10  11           11         NaN               NaN            NaN
# 11  12           12         NaN               NaN            NaN
# 12  13           13         NaN               NaN            NaN
# ...

# %% [markdown]
# # * see data from last

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # *to check the name of the columns

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %% [markdown]
# # * to see the data of a particular column

# %%
df["email"]
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %% [markdown]
# # * to check the datatype fo the columns

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df["fees"]
# Out:
# 0     $2.50 suggested donation for lunch for age 60 ...
# 1     None. Donations requested of clients who can a...
# 2                                                 None.
# 3     Vary according to income ($5-$90). Cash, check...
# 4         $60 application fee. Cash or checks accepted.
# 5     $55 per year membership dues. Classes have fee...
# 6     $85 per day. Vary according to income for thos...
# 7     Suggested donation of $4.25 per meal for senio...
# 8                                                 None.
# 9                                                 None.
# 10                                                None.
# 11                                                None.
# 12                                                None.
# 13                                                None.
# 14                                                None.
# 15    None for emergency services. Vary for after sc...
# 16                                                None.
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['location_id','fees','email','description']]
# Out:
#     location_id                                               fees  \
# 0             1  $2.50 suggested donation for lunch for age 60 ...
# 1             2  None. Donations requested of clients who can a...
# 2             3                                              None.
# 3             4  Vary according to income ($5-$90). Cash, check...
# 4             5      $60 application fee. Cash or checks accepted.
# 5             6  $55 per year membership dues. Classes have fee...
# 6             7  $85 per day. Vary according to income for thos...
# 7             8  Suggested donation of $4.25 per meal for senio...
# 8             9                                              None.
# 9            10                                              None.
# 10           11                                              None.
# 11           12                                              None.
# 12           13                                              None.
# ...

# %% [markdown]
# # * to check the data type of the columns

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# # *how to read excell files in jupiter notebook

# %%
pd.read_excel("LUSID Excel - Setting up your market data (1).xlsx")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df1=pd.read_excel("LUSID Excel - Setting up your market data (1).xlsx")
df1
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1['Unnamed: 7']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    LUSID also accepts UTC, UTS offsets and cutlabels
# 12                                                  NaN
# 13                                   Additional formats
# 14                                                  NaN
# 15                              Standard UTC timestamp:
# 16                                                  NaN
# ...

# %%
df1[[ 'Unnamed: 6','Unnamed: 9','Unnamed: 5']]
# Out:
#     Unnamed: 6                                         Unnamed: 9  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
df1.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# 5         NaN         NaN         NaN
# 6         NaN         NaN         NaN
# 7         NaN         NaN         NaN
# 8         NaN         NaN         NaN
# 9         NaN         NaN         NaN
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                 Datetimes in LUSID
# 2                                                NaN
# 3   This sheet allows you to format datetimes for...
# 4        If you have any questions please visit our:
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# ...

# %%
df1.tail()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 23         NaN         NaN         NaN        NaN
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                                           Unnamed: 4  \
# 23  Although the date can still appears without time
# 24                                               NaN
# 25                      Add an hour to your datetime
# 26                                               NaN
# 27              Subtract a minute from your datetime
#
#                     Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23  2019-04-10 13:30:45.550000         NaN        NaN        NaN        NaN
# 24                         NaN         NaN        NaN        NaN        NaN
# 25  2019-04-10 14:30:45.550000         NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# # * how to read data from website

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df2['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df2['Survived'])
# Out:
# pandas.core.series.Series

# %%
df2[['Name','Age','Fare']]
# Out:
#                                                   Name   Age     Fare
# 0                              Braund, Mr. Owen Harris  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                             Allen, Mr. William Henry  35.0   8.0500
# ..                                                 ...   ...      ...
# 886                              Montvila, Rev. Juozas  27.0  13.0000
# 887                       Graham, Miss. Margaret Edith  19.0  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  23.4500
# 889                              Behr, Mr. Karl Howell  26.0  30.0000
# 890                                Dooley, Mr. Patrick  32.0   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# # * how to read html file in pandas

# %%
df3=pd.read_html("https://www.basketball-reference.com/")

# %%
df3
# Out:
# [          East Unnamed: 1 Unnamed: 2   W   L
#  0    BOS * (1)          F          $  64  18
#  1    NYK * (2)          F          $  50  32
#  2    MIL * (3)          F          $  49  33
#  3    CLE * (4)          F          $  48  34
#  4    ORL * (5)          F          $  47  35
#  5    IND * (6)          F          $  47  35
#  6    PHI * (7)          F          $  47  35
#  7    MIA * (8)          F          $  46  36
#  8    CHI x (9)          F          $  39  43
#  9   ATL x (10)          F          $  36  46
#  10  BRK x (11)          F          $  32  50
#  11  TOR x (12)          F          $  25  57
#  12  CHO x (13)          F          $  21  61
#  13  WAS x (14)          F          $  15  67
#  14  DET x (15)          F          $  14  68,
#            West Unnamed: 1 Unnamed: 2   W   L
#  0    OKC * (1)          F          $  57  25
#  1    DEN * (2)          F          $  57  25
#  2    MIN * (3)          F          $  56  26
# ...

# %%
df4=pd.read_html("https://www.basketball-reference.com/teams/#teams_active")

# %%
df4
# Out:
# [                Franchise   Lg     From       To  Yrs     G     W     L  \
#  0           Atlanta Hawks  NBA  1949-50  2023-24   75  5937  2927  3010
#  1           Atlanta Hawks  NBA  1968-69  2023-24   56  4519  2229  2290
#  2         St. Louis Hawks  NBA  1955-56  1967-68   13  1005   553   452
#  3         Milwaukee Hawks  NBA  1951-52  1954-55    4   281    91   190
#  4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2   132    54    78
#  ..                    ...  ...      ...      ...  ...   ...   ...   ...
#  80     Washington Bullets  NBA  1974-75  1996-97   23  1886   887   999
#  81        Capital Bullets  NBA  1973-74  1973-74    1    82    47    35
#  82      Baltimore Bullets  NBA  1963-64  1972-73   10   813   401   412
#  83        Chicago Zephyrs  NBA  1962-63  1962-63    1    80    25    55
#  84        Chicago Packers  NBA  1961-62  1961-62    1    80    18    62
#
#       W/L%  Plyfs  Div  Conf  Champ
#  0   0.493     49   12     0      1
# ...

# %%
len(df4)
# Out:
# 2

# %%
df3=df4

# %%
df3
# Out:
# [                Franchise   Lg     From       To  Yrs     G     W     L  \
#  0           Atlanta Hawks  NBA  1949-50  2023-24   75  5937  2927  3010
#  1           Atlanta Hawks  NBA  1968-69  2023-24   56  4519  2229  2290
#  2         St. Louis Hawks  NBA  1955-56  1967-68   13  1005   553   452
#  3         Milwaukee Hawks  NBA  1951-52  1954-55    4   281    91   190
#  4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2   132    54    78
#  ..                    ...  ...      ...      ...  ...   ...   ...   ...
#  80     Washington Bullets  NBA  1974-75  1996-97   23  1886   887   999
#  81        Capital Bullets  NBA  1973-74  1973-74    1    82    47    35
#  82      Baltimore Bullets  NBA  1963-64  1972-73   10   813   401   412
#  83        Chicago Zephyrs  NBA  1962-63  1962-63    1    80    25    55
#  84        Chicago Packers  NBA  1961-62  1961-62    1    80    18    62
#
#       W/L%  Plyfs  Div  Conf  Champ
#  0   0.493     49   12     0      1
# ...

# %% [markdown]
# # PANDAS PART-2

# %% [markdown]
# # 1. operations in pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # * describe function
#  it shows the staticiscal operations on dataset

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
 df[df.dtypes[df.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
 df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
 df[df.dtypes[df.dtypes=="int64"].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
 df[df.dtypes[df.dtypes=="float64"].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
df[['Ticket']][4:16]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Name']][2:11]
# Out:
#                                                  Name
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 6                             McCarthy, Mr. Timothy J
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut

# %%
df[['Name','Age']][2:11]
# Out:
#                                                  Name   Age
# 2                              Heikkinen, Miss. Laina  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                            Allen, Mr. William Henry  35.0
# 5                                    Moran, Mr. James   NaN
# 6                             McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master. Gosta Leonard   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0

# %%
df[['Name','Age','Cabin']][2:11:2]
# Out:
#                                                  Name   Age Cabin
# 2                              Heikkinen, Miss. Laina  26.0   NaN
# 4                            Allen, Mr. William Henry  35.0   NaN
# 6                             McCarthy, Mr. Timothy J  54.0   E46
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0   NaN
# 10                    Sandstrom, Miss. Marguerite Rut   4.0    G6

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # * how to add columns in the dataset

# %%
df['new_col']=2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # * to add columns in between index

# %%
df.insert(loc=3,column='Food',value=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     1
# 1              2         1       1     1
# 2              3         1       3     1
# 3              4         1       1     1
# 4              5         0       3     1
# ..           ...       ...     ...   ...
# 886          887         0       2     1
# 887          888         1       1     1
# 888          889         0       3     1
# 889          890         1       1     1
# 890          891         0       3     1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     1
# 1            2         1       1     1
# 2            3         1       3     1
# 3            4         1       1     1
# 4            5         0       3     1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2
# ...

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %% [markdown]
# # * to find how many categories present inside the data

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     1
# 1            2         1       1     1
# 2            3         1       3     1
# 3            4         1       1     1
# 4            5         0       3     1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2
# ...

# %%
df[df['Age']>18]
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     1
# 1              2         1       1     1
# 2              3         1       3     1
# 3              4         1       1     1
# 4              5         0       3     1
# ..           ...       ...     ...   ...
# 885          886         0       3     1
# 886          887         0       2     1
# 887          888         1       1     1
# 889          890         1       1     1
# 890          891         0       3     1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# # * to check total nyumber of people greater than 18 years

# %%
len(df[df['Age']>18])
# Out:
# 575

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass   Food         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.0  714.000000  891.000000
# mean    446.000000    0.383838    2.308642    1.0   29.699118    0.523008
# std     257.353842    0.486592    0.836071    0.0   14.526497    1.102743
# min       1.000000    0.000000    1.000000    1.0    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000    1.0   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000    1.0   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.0   38.000000    1.000000
# max     891.000000    1.000000    3.000000    1.0   80.000000    8.000000
#
#             Parch        Fare  new_col
# count  891.000000  891.000000    891.0
# mean     0.381594   32.204208      2.0
# std      0.806057   49.693429      0.0
# min      0.000000    0.000000      2.0
# 25%      0.000000    7.910400      2.0
# 50%      0.000000   14.454200      2.0
# ...

# %%
df[df['Fare']>32.204208]
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 1              2         1       1     1
# 3              4         1       1     1
# 6              7         0       1     1
# 23            24         1       1     1
# 27            28         0       1     1
# ..           ...       ...     ...   ...
# 856          857         1       1     1
# 863          864         0       3     1
# 867          868         0       1     1
# 871          872         1       1     1
# 879          880         1       1     1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass  Food                              Name  \
# 179          180         0       3     1               Leonard, Mr. Lionel
# 263          264         0       1     1             Harrison, Mr. William
# 271          272         1       3     1      Tornquist, Mr. William Henry
# 277          278         0       2     1       Parkes, Mr. Francis "Frank"
# 302          303         0       3     1   Johnson, Mr. William Cahoone Jr
# 413          414         0       2     1    Cunningham, Mr. Alfred Fleming
# 466          467         0       2     1             Campbell, Mr. William
# 481          482         0       2     1  Frost, Mr. Anthony Wood "Archie"
# 597          598         0       3     1               Johnson, Mr. Alfred
# 633          634         0       1     1     Parr, Mr. William Henry Marsh
# 674          675         0       2     1        Watson, Mr. Ennis Hastings
# ...

# %%
len(df[df['Sex']=="male"])
# Out:
# 577

# %%
len(df[df['Sex']=="female"])
# Out:
# 314

# %%
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 1              2         1       1     1
# 3              4         1       1     1
# 6              7         0       1     1
# 11            12         1       1     1
# 23            24         1       1     1
# ..           ...       ...     ...   ...
# 871          872         1       1     1
# 872          873         0       1     1
# 879          880         1       1     1
# 887          888         1       1     1
# 889          890         1       1     1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ...

# %%
len(df[df['Pclass']==1])
# Out:
# 216

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 1              2         1       1     1
# 2              3         1       3     1
# 3              4         1       1     1
# 8              9         1       3     1
# 9             10         1       2     1
# ..           ...       ...     ...   ...
# 875          876         1       3     1
# 879          880         1       1     1
# 880          881         1       2     1
# 887          888         1       1     1
# 889          890         1       1     1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
len(df[df['Survived']==0])
# Out:
# 549

# %%
df['Sex']=='male'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Sex, Length: 891, dtype: bool

# %%
df["Fare"]>32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[(df['Sex']=='male')& (df["Fare"]>32)]
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 1              2         1       1     1
# 3              4         1       1     1
# 6              7         0       1     1
# 23            24         1       1     1
# 27            28         0       1     1
# ..           ...       ...     ...   ...
# 856          857         1       1     1
# 863          864         0       3     1
# 867          868         0       1     1
# 871          872         1       1     1
# 879          880         1       1     1
#
#                                                   Name   Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  male  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  male  35.0      1
# 6                              McCarthy, Mr. Timothy J  male  54.0      0
# 23                        Sloper, Mr. William Thompson  male  28.0      0
# 27                      Fortune, Mr. Charles Alexander  male  19.0      3
# ...

# %%
df[(df['Sex']=='female')& (df["Fare"]>32)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Food, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, new_col]
# Index: []

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df["Fare"])
# Out:
# 0.0

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass  Food                                Name  \
# 258          259         1       1     1                    Ward, Miss. Anna
# 679          680         1       1     1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1     1              Lesurer, Mr. Gustave J
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  male  35.0      0      0  PC 17755  512.3292          NaN        C
# 679  male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737  male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      new_col
# 258        2
# 679        2
# 737        2

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  \
# 0            1         0       3     1
# 1            2         1       1     1
# 2            3         1       3     1
# 3            4         1       1     1
# 4            5         0       3     1
#
#                                                 Name   Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris  male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  male  38.0      1
# 2                             Heikkinen, Miss. Laina  male  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  male  35.0      1
# 4                           Allen, Mr. William Henry  male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2
# ...

# %%
df[["Ticket","Fare","Cabin"]][0:4]
# Out:
#              Ticket     Fare Cabin
# 0         A/5 21171   7.2500   NaN
# 1          PC 17599  71.2833   C85
# 2  STON/O2. 3101282   7.9250   NaN
# 3            113803  53.1000  C123

# %% [markdown]
# #  location
# 1. iloc
# 2. loc

# %%
df.iloc[0:4,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1

# %%
df.loc[0:6,["Ticket","Fare","Cabin"]]
# Out:
#              Ticket     Fare Cabin
# 0         A/5 21171   7.2500   NaN
# 1          PC 17599  71.2833   C85
# 2  STON/O2. 3101282   7.9250   NaN
# 3            113803  53.1000  C123
# 4            373450   8.0500   NaN
# 5            330877   8.4583   NaN
# 6             17463  51.8625   E46
